# %%
import numpy as np
import pandas as pd
import sqlalchemy
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.neighbors import DistanceMetric
from math import radians
# !pip install pymysql
student_conn_string = "mysql+pymysql://student:p7%40vw7MCatmnKjy7@data.engeto.com/data"
engeto_data_conn = sqlalchemy.create_engine(student_conn_string)
bikes_df = pd.read_sql("select * from edinburgh_bikes", engeto_data_conn)
weather_df = pd.read_sql("select * from edinburgh_weather", engeto_data_conn)
# Out:
# WARNING: You are using pip version 21.2.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'c:\users\42073\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pymysql in c:\users\42073\appdata\local\programs\python\python39\lib\site-packages (1.0.2)

# %% [markdown]
# ##Průzkum dat:

# %%
df_cchls = bikes_df[bikes_df['start_station_name'] == 'City Chambers Launch Station']
df_cchls
# Out:
#         index           started_at             ended_at  duration  \
# 158413    270  2020-03-02 08:35:36  2020-03-02 08:40:32       296
#
#         start_station_id            start_station_name  \
# 158413              1857  City Chambers Launch Station
#
#                  start_station_description  start_station_latitude  \
# 158413  Temporary station at City Chambers               55.950222
#
#         start_station_longitude  end_station_id end_station_name  \
# 158413                 -3.19027             296   Castle Terrace
#
#                             end_station_description  end_station_latitude  \
# 158413  Corner of Castle Terrace and Lady Lawson St             55.946766
#
#         end_station_longitude
# 158413              -3.202038

# %%
#Upravuji jména start_station_name a end_station_name, kde jsou viditelné překlepy, aby se mi informace o stanicích dle jejich 
#jmen dobře spojily. Měním 'Picady Place' na 'Picardy Place', 'Bruntsfield links' na 'Bruntsfield Links' a 'Waitrose, Comely Bank' na 'Waitrose Comely Bank'. 
bikes_df1 = bikes_df.replace({'Picady Place': 'Picardy Place', 'Bruntsfield links': 'Bruntsfield Links', 'Waitrose, Comely Bank' : 'Waitrose Comely Bank'})

# %%
df_neparove = bikes_df[~bikes_df.end_station_name.isin(bikes_df.start_station_name)]
df_neparove
# Out:
#        index           started_at             ended_at  duration  \
# 7263    1126  2018-11-08 09:05:20  2018-11-08 09:34:33      1753
# 8958    2821  2018-11-19 09:28:14  2018-11-19 09:48:29      1215
# 27538   4304  2019-03-22 12:15:48  2019-03-22 13:24:21      4112
# 27541   4307  2019-03-22 12:44:51  2019-03-23 07:41:04     68173
# 27712   4478  2019-03-23 13:20:22  2019-03-23 14:19:19      3536
#
#        start_station_id  start_station_name  \
# 7263                183     Waverley Bridge
# 8958                251    Waverley Station
# 27538               349  Orchard Brae House
# 27541               357      Macdonald Road
# 27712               189       City Chambers
#
#                             start_station_description  start_station_latitude  \
# 7263                   near the top of the South ramp               55.951344
# 8958             Platform level near Calton Road Exit               55.952641
# 27538  Outside Orchard Brae House on Queensferry Road               55.955083
# 27541                                  Macdonald Road               55.963995
# 27712                        City Chambers Quadrangle               55.950109
#
#        start_station_longitude  end_station_id        end_station_name  \
# 7263                 -3.191421             242           Virtual Depot
# 8958                 -3.187527             242           Virtual Depot
# 27538                -3.223634             280  Smarter Travel Station
# 27541                -3.185189             280  Smarter Travel Station
# 27712                -3.190258             280  Smarter Travel Station
#
#       end_station_description  end_station_latitude  end_station_longitude
# 7263            Virtual Depot             55.972402              -3.155794
# 8958            Virtual Depot             55.972402              -3.155794
# 27538              The Street             53.395525              -2.990138
# 27541              The Street             53.395525              -2.990138
# 27712              The Street             53.395525              -2.990138

# %%
bikes_df['start_station_name'].nunique()
# Out:
# 169

# %%
bikes_df['end_station_name'].nunique()
# Out:
# 170

# %%
bikes_df['start_station_id'].nunique()
# Out:
# 198

# %%
bikes_df['end_station_id'].nunique()
# Out:
# 199

# %%
#Zjišťuji si základní informace o DataFrame tabulce bikes_df. 
bikes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438259 entries, 0 to 438258
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      438259 non-null  int64
#  1   started_at                 438259 non-null  object
#  2   ended_at                   438259 non-null  object
#  3   duration                   438259 non-null  int64
#  4   start_station_id           438259 non-null  int64
#  5   start_station_name         438259 non-null  object
#  6   start_station_description  435549 non-null  object
#  7   start_station_latitude     438259 non-null  float64
#  8   start_station_longitude    438259 non-null  float64
#  9   end_station_id             438259 non-null  int64
#  10  end_station_name           438259 non-null  object
#  11  end_station_description    435256 non-null  object
#  12  end_station_latitude       438259 non-null  float64
#  13  end_station_longitude      438259 non-null  float64
# dtypes: float64(4), int64(4), object(6)
# memory usage: 46.8+ MB

# %%
tabulka_id = bikes_df[['start_station_id', 'start_station_name']].sort_values(by='start_station_name').drop_duplicates()

# %%
#Vytvořila jsem si pomocné tabulky, kde jsem pak snadno mohla porovnat id a jména stanic. 
tabulka_id.to_csv('tabulka_id2.csv')

# %% [markdown]
# Tabulka edingburgh_bikes má celkem 438_259 řádků a 14 sloupců. Nulové hodnoty jsou ve dvou sloupcích, ve start_station_description (2710 NaN hodnot) a v end_station_description(3003 NaN hodnot). Jelikož mi tyto NaN hodnoty pro výpočty nijak nevadí, nebudu je umazávat, přišla bych tak o cenné řádky, které by mohly zkreslit výsledky.
#
# Celkem je v tabulce 170 různých "end_station_name" a 169 "start_station_name". Je zde 198 různých id stanic (start_station_id) a 199 end_station_id. DataFrame df_cchls - City Chambers Launch Station - dle popisu je to jen dočasná stanice, je odtud jen jediný výjezd/start (2. 3. 2020), žádný příjezd na tuto stanici není. Potom jsou zde dvě stanice, kde je jen vrácení kol, žádný odjezd z nich není: Smarter Travel Station (vrácení tří kol v období 22. - 23. 3. 2019) a Virtual Depot (vrácení dvou kol v listopadu 2018).
#
# Je zde několik stanic, které mají dvě id (či mají dvě stanice shodné id). Vypadá to, že v průběhu doby došlo ke změnám a některé stanice se umístily trošku jinam (mají trošičku jinou zeměpisnou šířku i délku a změnilo se i jejich id). Tím, že ve výpočtech budu používat seskupování dle jmen stanic a nikoliv dle jejich id, tak mne tento nesoulad v id nijak nevadí.
#
# Brunswick Place a Brunswick Place - Virtual mají shodné id 261. Brunswick Place má navíc dvě id: 261 a 1769. Bruntsfield a Bruntsfield links (evidentně překlep v názvu s malým "l") mají shodné id 290. Bruntsfield Links má id 1767. Meadow Place a Meadow Place 2 mají shodné id 1024. Meadow Place má navíc ještě i id: 340. Picardy Place a Picady Place (překlep, v tabulce jsou dva záznamy ze dne 9. 10. 2020) a mají id 2268. Dudley Gardens a Newhaven Road / Dudley Gardens mají shodné id 366. Dudley Gardens má navíc ještě další id: 1095. Hillside Crescent a Hillside Crescent 2 mají shodné id 870. Hillside Crescent má navíc ještě jedno id: 1090. Haymarket - Murrayfield Rugby Event a Sustrans - walk cycle event mají shodné id 965. RHC - Edingburgh Festival Camping (05th to 26th August) a Royal Highland Show - West Gate (19th to 23rd June) mají shodné id 981. Hunter Square a The Tron mají také shodné id 1028. Causewayside má dvě id: 1727 a 359. Colinton Road má také dvě id: 345 a 1748. Comely Bank Road má dvě id: 866 a 1763. Corstorphine Road má dvě id: 873 a 1747. Craigleith Road: 1764 a 865. Cramond Foreshore: 862 a 1722. Crichton Street: 888 a 1017. Dalry Road Lidl: 1092 a 350. Dundas Street: 1720 a 868. Dundee Terrace: 352 a 1025. EICC: 882 a 1050. East London Street: 1730 a 356. Edingburgh Zoo: 1725 a 874. Gamekeeper´s Road: 863 a 1807. Gladstone Terrace: 879 a 1097. Heriot Watt - Edingburgh Business School - 1819 a 1723. Hunter Square: 1018 a 1028. Inverleith Row: 1737 a 355. Logie Green Road: 1743 a 880. Marchmont Crescent: 344 a 1098. Milton Road - Edingburgh College: 1813 a 1041. Morningside Road: 346 a 1744. Murrayfield: 876 a 1799. Murrayfield Tram: 1754 a 889. Queen Margaret University: 1758 a 1033. Roseburn Street: 1055 a 887. Sighthill - Edingburgh College: 1815 a 1040. Simon Square: 347 a 1726. South Trinity Road: 1038 a 354. Thirlestane Road: 1768 a 343. Tollcross: 881 a 1721. Waitrose Comely Bank (1753) a Waitrose, Comely Bank(277) (překlep). Warrender Park Road: 1051 a 341. West Crosscauseway: 1096 a 890. Wester Coates Terrace: 885 a 1738.
#
# Pro analýzu budu dále pracovat s nově vytvořeným DataFramem bikes_df2, ve kterém jsou opravené překlepy u tří stanic a také je vybrán omezenější časový úsek (data od 1. 1. 2020 do konce).

# %%
#DataFrame bikes_df2 - vybírám jen data od 1. 1. 2020 až po ta letošní, nejnovější.
bikes_df2 = bikes_df1[bikes_df['started_at']>'2020-01-01']
bikes_df2.head()
# Out:
#         index           started_at             ended_at  duration  \
# 138796      0  2020-01-01 00:11:49  2020-01-01 00:32:37      1247
# 138797      1  2020-01-01 00:15:47  2020-01-01 00:24:48       541
# 138798      2  2020-01-01 00:21:32  2020-01-01 01:02:45      2473
# 138799      3  2020-01-01 00:24:10  2020-01-01 01:02:52      2322
# 138800      4  2020-01-01 00:46:13  2020-01-01 01:01:06       893
#
#         start_station_id        start_station_name  \
# 138796              1738     Wester Coates Terrace
# 138797              1024              Meadow Place
# 138798               256          St Andrews House
# 138799               256          St Andrews House
# 138800              1756  Western General Hospital
#
#              start_station_description  start_station_latitude  \
# 138796  Junction with Roseburn Terrace               55.945648
# 138797             End of Meadow Place               55.940238
# 138798            beside Jacobs ladder               55.953164
# 138799            beside Jacobs ladder               55.953164
# 138800                Porterfield Road               55.963454
#
#         start_station_longitude  end_station_id  end_station_name  \
# 138796                -3.231847            1725     Edinburgh Zoo
# 138797                -3.194640             265      Meadows East
# 138798                -3.181682             259  St Andrew Square
# 138799                -3.181682             259  St Andrew Square
# 138800                -3.232909            1095    Dudley Gardens
#
#                         end_station_description  end_station_latitude  \
# 138796             Corstorphine Road, Edinburgh             55.942115
# 138797    Between Melville Terrace and Sciennes             55.939809
# 138798                        North East corner             55.954906
# 138799                        North East corner             55.954906
# 138800  Opposite Victoria Park on Newhaven Road             55.975940
#
#         end_station_longitude
# 138796              -3.269287
# 138797              -3.182739
# 138798              -3.192444
# 138799              -3.192444
# 138800              -3.191321

# %% [markdown]
# ##Identifikujte aktivní a neaktivní stanice.
#
# ##Identifikujte nejfrekventovanější stanice.

# %%
bikes_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299463 entries, 138796 to 438258
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      299463 non-null  int64
#  1   started_at                 299463 non-null  object
#  2   ended_at                   299463 non-null  object
#  3   duration                   299463 non-null  int64
#  4   start_station_id           299463 non-null  int64
#  5   start_station_name         299463 non-null  object
#  6   start_station_description  296753 non-null  object
#  7   start_station_latitude     299463 non-null  float64
#  8   start_station_longitude    299463 non-null  float64
#  9   end_station_id             299463 non-null  int64
#  10  end_station_name           299463 non-null  object
#  11  end_station_description    296460 non-null  object
#  12  end_station_latitude       299463 non-null  float64
#  13  end_station_longitude      299463 non-null  float64
# dtypes: float64(4), int64(4), object(6)
# memory usage: 34.3+ MB

# %%
#Toto je DataFrame df, kde je nový sloupec count (cnt) a agregovaný počet stanic a odjezdy z nich. 
df = bikes_df2.loc[:, ['started_at', 'start_station_name', 'start_station_latitude', 'start_station_longitude']]
df.columns = ['date','station', 'lat', 'lon']
df = df.assign(cnt=1).groupby('station').agg({'lat': 'mean', 'lon' : 'mean', 'cnt' : 'sum'})

# %%
#Zde je deset stanic, na kterých si lidé nejčastěji kola půjčují a vyjíždějí z nich. 
df = df.sort_values(by='cnt', ascending=True)
df.tail(10)
# Out:
#                                lat       lon    cnt
# station
# Leith Walk               55.965052 -3.176640   5911
# St Andrew Square         55.954906 -3.192444   5947
# Pollock Halls            55.940081 -3.171747   6064
# Cramond Foreshore        55.980031 -3.300642   6519
# Bruntsfield Links        55.937123 -3.206432   6874
# Victoria Quay            55.977617 -3.174126   7251
# Duke Street              55.969012 -3.167395   7288
# Meadow Place             55.940238 -3.194640   9647
# Meadows East             55.939809 -3.182739  11392
# Portobello - Kings Road  55.957915 -3.118332  11621

# %%
#Toto je dataframe df_end, kde jsou koncové stanice a agregovaný součet příjezdů tam.
df_end = bikes_df2.loc[:, ['ended_at', 'end_station_name', 'end_station_latitude', 'end_station_longitude']]
df_end.columns = ['date','station', 'lat', 'lon']
df_end = df_end.assign(cnt=1).groupby('station').agg({'lat': 'mean', 'lon' : 'mean', 'cnt' : 'sum'})

# %%
#Zde je deset stanic, na kterých lidé nejčastěji kola vrací.
df_end = df_end.sort_values(by='cnt', ascending=True)
df_end.tail(10)
# Out:
#                                lat       lon    cnt
# station
# Brunswick Place          55.960852 -3.180986   5507
# Dynamic Earth            55.951089 -3.175725   5824
# Canonmills               55.962804 -3.196284   6208
# Meadow Place             55.940238 -3.194640   7386
# Leith Walk               55.965051 -3.176644   7550
# Cramond Foreshore        55.980031 -3.300642   7775
# Meadows East             55.939809 -3.182739   9658
# Victoria Quay            55.977617 -3.174126  10030
# Duke Street              55.969012 -3.167395  11264
# Portobello - Kings Road  55.957915 -3.118332  16301

# %%
#Vytvářím nový sloupec 'soucet_prijezdu_a_vraceni' = součet pohybů na jednotlivých stanicích (součet odjezdů a příjezdů).
df['soucet_prijezdu_a_vraceni'] = df['cnt'] + df_end['cnt']
df.head()
# Out:
#                                                           lat       lon  cnt  \
# station
# City Chambers Launch Station                        55.950222 -3.190270    1
# Heriot Watt - Student Accomodation (Anna MacLeo...  55.908404 -3.328825    6
# Fountain Court  - Apartments (RESIDENTS ONLY)       55.943806 -3.211238    8
# Eden Locke - Aparthotel (RESIDENTS ONLY)            55.952619 -3.205678    9
# Scotstoun House                                     55.981107 -3.394211  128
#
#                                                     soucet_prijezdu_a_vraceni
# station
# City Chambers Launch Station                                              NaN
# Heriot Watt - Student Accomodation (Anna MacLeo...                        8.0
# Fountain Court  - Apartments (RESIDENTS ONLY)                            16.0
# Eden Locke - Aparthotel (RESIDENTS ONLY)                                 16.0
# Scotstoun House                                                         250.0

# %%
#Rozdíl mezi počtem příjezdů a počtem odjezdů ze stanic; čím je číslo větší/kladnější, tím se zde kola více chybí, čím je číslo menší, zápornější, tím se zde kola více hromadí.
df['rozdil_prijezd_odjezd'] =  df['cnt'] - df_end['cnt']
df.head()
# Out:
#                                                           lat       lon  cnt  \
# station
# City Chambers Launch Station                        55.950222 -3.190270    1
# Heriot Watt - Student Accomodation (Anna MacLeo...  55.908404 -3.328825    6
# Fountain Court  - Apartments (RESIDENTS ONLY)       55.943806 -3.211238    8
# Eden Locke - Aparthotel (RESIDENTS ONLY)            55.952619 -3.205678    9
# Scotstoun House                                     55.981107 -3.394211  128
#
#                                                     soucet_prijezdu_a_vraceni  \
# station
# City Chambers Launch Station                                              NaN
# Heriot Watt - Student Accomodation (Anna MacLeo...                        8.0
# Fountain Court  - Apartments (RESIDENTS ONLY)                            16.0
# Eden Locke - Aparthotel (RESIDENTS ONLY)                                 16.0
# Scotstoun House                                                         250.0
#
#                                                     rozdil_prijezd_odjezd
# station
# City Chambers Launch Station                                          NaN
# Heriot Watt - Student Accomodation (Anna MacLeo...                    4.0
# Fountain Court  - Apartments (RESIDENTS ONLY)                         0.0
# Eden Locke - Aparthotel (RESIDENTS ONLY)                              2.0
# Scotstoun House                                                       6.0

# %%
#Takto zjistím stanice, kde je nejvíc půjčení kol i jejich vrácení (sloupec soucet_prijezdu_a_vraceni), tedy nejfrekventovanější stanice a také ty nejméně aktivní. 
df = df.sort_values(by='soucet_prijezdu_a_vraceni', ascending=False)
df.tail(10)
#df.head(20)
# Out:
#                                                           lat       lon  cnt  \
# station
# Musselburgh Brunton Hall                            55.943964 -3.058318  294
# Edinburgh Park Central                              55.931169 -3.314414  221
# Tesco Ferrymuir                                     55.983766 -3.401352  219
# Port Edgar Marina                                   55.992957 -3.407156  195
# Ingliston Park & Ride                               55.938792 -3.355556  136
# Scotstoun House                                     55.981107 -3.394211  128
# Eden Locke - Aparthotel (RESIDENTS ONLY)            55.952619 -3.205678    9
# Fountain Court  - Apartments (RESIDENTS ONLY)       55.943806 -3.211238    8
# Heriot Watt - Student Accomodation (Anna MacLeo...  55.908404 -3.328825    6
# City Chambers Launch Station                        55.950222 -3.190270    1
#
#                                                     soucet_prijezdu_a_vraceni  \
# station
# Musselburgh Brunton Hall                                                673.0
# Edinburgh Park Central                                                  458.0
# Tesco Ferrymuir                                                         419.0
# Port Edgar Marina                                                       398.0
# Ingliston Park & Ride                                                   360.0
# Scotstoun House                                                         250.0
# Eden Locke - Aparthotel (RESIDENTS ONLY)                                 16.0
# Fountain Court  - Apartments (RESIDENTS ONLY)                            16.0
# Heriot Watt - Student Accomodation (Anna MacLeo...                        8.0
# City Chambers Launch Station                                              NaN
#
#                                                     rozdil_prijezd_odjezd
# station
# Musselburgh Brunton Hall                                            -85.0
# Edinburgh Park Central                                              -16.0
# Tesco Ferrymuir                                                      19.0
# Port Edgar Marina                                                    -8.0
# Ingliston Park & Ride                                               -88.0
# Scotstoun House                                                       6.0
# Eden Locke - Aparthotel (RESIDENTS ONLY)                              2.0
# Fountain Court  - Apartments (RESIDENTS ONLY)                         0.0
# Heriot Watt - Student Accomodation (Anna MacLeo...                    4.0
# City Chambers Launch Station                                          NaN

# %% [markdown]
# Frekventované a nefrekventované stanice
#
#
# Na těchto stanicích si lidé nejčastěji půjčují kola: Portobello - Kings Road, Meadows East, Meadow Place, Duke Street, Victoria Quay, Bruntsfield Links, Cramond Foreshore, Pollock Halls, St Andrew Square, Leith Walk.
#
# Na těchto stanicích lidé kola nejčastěji vracejí: Portobello - Kings Road, Duke Street, Victoria Quay, Meadows East, Cramond Foreshore, Leith Walk, Meadow Place, Canonmills, Dynamic Earth, Brunswick Place.
#
# Toto jsou nejfrekventovanější stanice co do počtu součtu jak půjčení kol, tak i jejich vrácení: Portobello - Kings Road, Meadows East, Meadow Place, Duke Street, Victoria Quay, Bruntsfield Links, Cramond Foreshore, Pollock Halls, St Andrew Square, Leith Walk, Canonmills, Bruntsfield Links, Brunswick Place.
#
# Toto jsou naopak nejméně frekventované stanice, kde půjčení a vrácení kol není moc časté: Heriot Watt - Student Accomodation (Anna MacLeod Halls), Fountain Court - Apartments (RESIDENTS ONLY), Eden Locke - Aparthotel (RESIDENTS ONLY), Scotstoun House, Ingliston Park & Ride, Port Edgar Marina, Tesco Ferrymuir, Edinburgh Park Central, Musselburgh Brunton Hall.

# %% [markdown]
# Aktivní versus neaktivní stanice
#
# Za aktivní stanice považuji takové, které jsou v provozu a dají se na nich kola aktuálně půjčit. Za neaktivní naopak ty, které mají spíše dočasný charakter a bývají zřejmě v provozu jen kvůli nějaké příležitosti (ať už například nějakým opravám či například sportovním událostem).
#
# Toto jsou neaktivní stanice: City Chambers Launch Station (dočasná stanice, je odtud jen jediný výjezd/start (2. 3. 2020)), Royal Highland Show - West Gate (19th to 23rd June)(dočasná stanice využitá jen 21. 6. 2019), Comely Bank, Cycling Scotland Conference (v provozu zřejmě jen dočasně ve dnech 4.-5. 11. 2019), Pleasance - Edinburgh University Sports Fair (v provozu zřejmě jen dočasně ve dnech 11.-12. 9. 2019). Další neaktivní, dočasné stanice jsou tyto: Fort Kinnaird, Depot Virtual, Sustrans - walk cycle event, Novotel, Holyrood Park - Woman's Tour Of Scotland (Event 11/08/19), Corn Exchange - walk cycle event, Royal Highland Show - East Gate (19th to 23rd June), Crescent House, Ingliston Park and Ride (19th to 23rd June), Corstorphine Road - Pinkhill, Royal Infirmary, Haymarket - Murrayfield Rugby Event, West Newington Place, Dunbar’s Close Garden, Smarter Travel Station..

# %% [markdown]
# ##Identifikujte stanice, na kterých se kola hromadí a stanice, kde potenciálně chybí.

# %%
#Takto zjistím, kde kola potenciálně chybí a kde přebívají; čím je číslo větší/kladnější, 
#tím se zde kola více chybí, čím je číslo menší, zápornější, tím se zde kola více hromadí.

df = df.sort_values(by='rozdil_prijezd_odjezd')
df.head(6)
# Out:
#                                lat       lon    cnt  \
# station
# Portobello - Kings Road  55.957915 -3.118332  11621
# Duke Street              55.969012 -3.167395   7288
# Victoria Quay            55.977617 -3.174126   7251
# Leith Walk               55.965052 -3.176640   5911
# Cramond Foreshore        55.980031 -3.300642   6519
# Dynamic Earth            55.951089 -3.175725   4694
#
#                          soucet_prijezdu_a_vraceni  rozdil_prijezd_odjezd
# station
# Portobello - Kings Road                    27922.0                -4680.0
# Duke Street                                18552.0                -3976.0
# Victoria Quay                              17281.0                -2779.0
# Leith Walk                                 13461.0                -1639.0
# Cramond Foreshore                          14294.0                -1256.0
# Dynamic Earth                              10518.0                -1130.0

# %% [markdown]
# Kola potenciálně chybí na těchto stanicích: Bruntsfield Links, Meadow Place, Bristo Square, Pollock Halls, Charlotte Square.
#
# Kola potenciálně přebívají: Portobello - Kings Road, Duke Street, Victoria Quay, Leith Walk, Cramond Foreshore.

# %% [markdown]
# ##Jak dlouho trvá jedna výpůjčka? Najděte odlehlé hodnoty, zobrazte histogram.

# %%
#Zde je DataFrame df_duration
df_duration = bikes_df2.loc[:, ['duration']]
df_duration.head()
# Out:
#         duration
# 138796      1247
# 138797       541
# 138798      2473
# 138799      2322
# 138800       893

# %%
#Tady se mi zobrazí stanice, které zvyšují celkový průměr doby jedné výpůjčky. 
d = bikes_df2.query("duration > 200000")
d
# Out:
#         index           started_at             ended_at  duration  \
# 141002   2206  2020-01-10 15:46:22  2020-01-22 14:40:21   1032838
# 148223   9427  2020-01-30 19:03:49  2020-02-03 16:51:15    337646
# 161588   3445  2020-03-07 13:18:28  2020-03-15 16:04:37    701168
#
#         start_station_id        start_station_name  \
# 141002               247          Charlotte Square
# 148223               289             Castle Street
# 161588              1756  Western General Hospital
#
#                start_station_description  start_station_latitude  \
# 141002  North Corner of Charlotte Square               55.952335
# 148223                  Near Rose Street               55.951501
# 161588                  Porterfield Road               55.963454
#
#         start_station_longitude  end_station_id end_station_name  \
# 141002                -3.207101            1748    Colinton Road
# 148223                -3.203184             358       Leith Walk
# 161588                -3.232909             264    Pollock Halls
#
#                          end_station_description  end_station_latitude  \
# 141002  Near Napier University Merchiston Campus             55.933416
# 148223        Leith Walk opposite Dalmeny Street             55.965040
# 161588                    Pollock Halls Entrance             55.940081
#
#         end_station_longitude
# 141002              -3.212397
# 148223              -3.176686
# 161588              -3.171747

# %%
df_duration.hist(bins=[
  0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500, 8000, 8500, 9000, 9500, 10000
], color='green', edgecolor = 'black', alpha=0.75)
plt.title('Average duration of one loan', fontsize=20)
plt.xlabel('Average duration (in seconds)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Zobrazený histogram rozložení průměrných dob výpůjček ze stanic ukazuje, že nejvíce výpůjček trvá kolem 1000 sekund (cca 17 minut). Zobrazila jsem si tři výpůjčky, které mají nejdelší dobu půjčení. Dlouhá výpůjčka byla v období od 10. 1. 2020 do 22. ledna 2020. Další dlouhá výpůjčka byla od 7. 3. do 15. 3. 2020 a do třetice dlouhá výpůjčka je od 30. 1. do 3. 2. 2020.

# %% [markdown]
# ##Zobrazte vývoj poptávky po půjčování kol v čase.
#
# ##Identifikujte příčiny výkyvů poptávky.

# %%
#Přeměna na datový typ datetime a vytvoření nových sloupců "weekday": číselné rozlišení dnů v týdnu.
bikes_df2['started_at'] = pd.to_datetime(bikes_df2['started_at'])
bikes_df2['ended_at'] = pd.to_datetime(bikes_df2['ended_at'])
bikes_df2['weekday'] = bikes_df2['started_at'].dt.weekday
# Out:
# <ipython-input-24-199fce93d05e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikes_df2['started_at'] = pd.to_datetime(bikes_df2['started_at'])
# <ipython-input-24-199fce93d05e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikes_df2['ended_at'] = pd.to_datetime(bikes_df2['ended_at'])
# <ipython-input-24-199fce93d05e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikes_df2['weekday'] = bikes_df2['started_at'].dt.weekday

# %%
bikes_df2['just_date'] = bikes_df2['started_at'].dt.date
# Out:
# <ipython-input-25-3865865e3a53>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikes_df2['just_date'] = bikes_df2['started_at'].dt.date

# %%
novy_df = bikes_df2.set_index('just_date')
novy_df.head()
# Out:
#             index          started_at            ended_at  duration  \
# just_date
# 2020-01-01      0 2020-01-01 00:11:49 2020-01-01 00:32:37      1247
# 2020-01-01      1 2020-01-01 00:15:47 2020-01-01 00:24:48       541
# 2020-01-01      2 2020-01-01 00:21:32 2020-01-01 01:02:45      2473
# 2020-01-01      3 2020-01-01 00:24:10 2020-01-01 01:02:52      2322
# 2020-01-01      4 2020-01-01 00:46:13 2020-01-01 01:01:06       893
#
#             start_station_id        start_station_name  \
# just_date
# 2020-01-01              1738     Wester Coates Terrace
# 2020-01-01              1024              Meadow Place
# 2020-01-01               256          St Andrews House
# 2020-01-01               256          St Andrews House
# 2020-01-01              1756  Western General Hospital
#
#                  start_station_description  start_station_latitude  \
# just_date
# 2020-01-01  Junction with Roseburn Terrace               55.945648
# 2020-01-01             End of Meadow Place               55.940238
# 2020-01-01            beside Jacobs ladder               55.953164
# 2020-01-01            beside Jacobs ladder               55.953164
# 2020-01-01                Porterfield Road               55.963454
#
#             start_station_longitude  end_station_id  end_station_name  \
# just_date
# 2020-01-01                -3.231847            1725     Edinburgh Zoo
# 2020-01-01                -3.194640             265      Meadows East
# 2020-01-01                -3.181682             259  St Andrew Square
# 2020-01-01                -3.181682             259  St Andrew Square
# 2020-01-01                -3.232909            1095    Dudley Gardens
#
#                             end_station_description  end_station_latitude  \
# just_date
# 2020-01-01             Corstorphine Road, Edinburgh             55.942115
# 2020-01-01    Between Melville Terrace and Sciennes             55.939809
# 2020-01-01                        North East corner             55.954906
# 2020-01-01                        North East corner             55.954906
# 2020-01-01  Opposite Victoria Park on Newhaven Road             55.975940
#
#             end_station_longitude  weekday
# just_date
# 2020-01-01              -3.269287        2
# 2020-01-01              -3.182739        2
# 2020-01-01              -3.192444        2
# 2020-01-01              -3.192444        2
# 2020-01-01              -3.191321        2

# %%
#Spočítáme počet výpůjček za jednotlivé dny.
novy_df = novy_df.groupby('just_date').count()

# %%
novy_df[['index']]
# Out:
#             index
# just_date
# 2020-01-01    272
# 2020-01-02    159
# 2020-01-03    235
# 2020-01-04    251
# 2020-01-05    235
# ...           ...
# 2021-06-26    319
# 2021-06-27    523
# 2021-06-28    293
# 2021-06-29    405
# 2021-06-30    380
#
# [547 rows x 1 columns]

# %%
figure(num=1, figsize=(16, 7))
plt.plot(novy_df.index, novy_df['index'], color = 'green')
plt.xlabel('Date')
plt.title('Renting bicycles during the time', fontsize=20)
plt.ylabel('Number of rented bicycles', fontsize=12)
plt.show()

# %% [markdown]
# Z grafu vidíme, že na půjčování kol má vliv roční doba - během jara, léta a podzimu lidé tuto službu využívají více než přes zimu. Zároveň zde jde vidět i ohromný nárůst poptávky po kolech v období jara a léta 2020, což si můžeme vysvětlit, řekla bych, i pandemií Covidu (omezení hromadné dopravy, více volného času..).

# %% [markdown]
# ##Zjistěte vliv počasí na poptávku po kolech (údaje o počasí v Edinburghu jsou v tabulce edinburgh_weather).

# %%
#V DataFrame novy_df je groupby - datum a počet půjčených kol za daný den. 
novy_df[['index']]
# Out:
#             index
# just_date
# 2020-01-01    272
# 2020-01-02    159
# 2020-01-03    235
# 2020-01-04    251
# 2020-01-05    235
# ...           ...
# 2021-06-26    319
# 2021-06-27    523
# 2021-06-28    293
# 2021-06-29    405
# 2021-06-30    380
#
# [547 rows x 1 columns]

# %%
novy_df = novy_df.reset_index()

# %%
novy_df['datum'] = pd.to_datetime(novy_df['just_date'])

# %%
weather_df.rename(columns={'date': 'just_date'}, inplace=True)
df2 = weather_df.set_index('just_date')
df2['dest'] = df2['rain'].str.replace('mm', '')
df2["dest"] = df2.dest.astype(float)
df2 = df2.groupby('just_date').mean('rain').round(2)

# %%
df2 = df2.reset_index()

# %%
df2['datum'] = pd.to_datetime(df2['just_date'])

# %%
dest_df = pd.merge(novy_df, df2,on='datum',how='left')

# %%
dest_df.plot.scatter(x="dest", y="index", color="DarkGreen")
plt.ylabel('Number of rented bicycles per day', fontsize=14)
plt.title('Renting bicycles vs rainy days', fontsize=20)
plt.xlabel('Rain (mean of the day) in mm', fontsize=14)
plt.show()

# %% [markdown]
# Z grafu vidíme, že nejvíce půjčených kol bývá, když neprší, nebo když prší málo, nicméně ani drobný déšť není na půjčení kola překážkou.

# %% [markdown]
# Vztah mezi počtem výpůjček a dalšími vlivy počasí.

# %%
weather_df.tail(70)
# Out:
#        time   temp  feels              wind     gust    rain humidity cloud  \
# 8202  06:00  11 °c  12 °c    4 km/h from SW   4 km/h  0.0 mm      81%   13%
# 8203  09:00  14 °c  14 °c     8 km/h from W   9 km/h  0.0 mm      66%   47%
# 8204  12:00  17 °c  17 °c     9 km/h from W  10 km/h  0.0 mm      51%   20%
# 8205  15:00  18 °c  18 °c    10 km/h from W  11 km/h  0.0 mm      49%   21%
# 8206  18:00  16 °c  16 °c  17 km/h from WSW  21 km/h  0.0 mm      56%   13%
# ...     ...    ...    ...               ...      ...     ...      ...   ...
# 8267  09:00  14 °c  13 °c    12 km/h from E  14 km/h  0.0 mm      83%   90%
# 8268  12:00  16 °c  16 °c  12 km/h from ENE  14 km/h  0.0 mm      71%   29%
# 8269  15:00  17 °c  17 °c    10 km/h from E  12 km/h  0.0 mm      66%   67%
# 8270  18:00  16 °c  16 °c  13 km/h from ENE  15 km/h  0.0 mm      68%   20%
# 8271  21:00  13 °c  13 °c     6 km/h from E  12 km/h  0.0 mm      78%   69%
#
#      pressure        vis   just_date
# 8202  1022 mb  Excellent  2021-06-22
# 8203  1022 mb  Excellent  2021-06-22
# 8204  1021 mb  Excellent  2021-06-22
# 8205  1020 mb  Excellent  2021-06-22
# 8206  1021 mb  Excellent  2021-06-22
# ...       ...        ...         ...
# 8267  1019 mb  Excellent  2021-06-30
# 8268  1019 mb  Excellent  2021-06-30
# 8269  1019 mb  Excellent  2021-06-30
# 8270  1019 mb  Excellent  2021-06-30
# 8271  1020 mb  Excellent  2021-06-30
#
# [70 rows x 11 columns]

# %%
#DataFrame df4 - vztah mezi počtem výpůjček a teplotou
df4 = weather_df.set_index('just_date')
df4['teplota'] = df4['temp'].str.replace('°c', '')
df4["teplota"] = df4.teplota.astype(float)
df4 = df4.groupby('just_date').mean('temp').round(1)

# %%
df4.head()
# Out:
#             teplota
# just_date
# 2018-09-01     14.4
# 2018-09-02     16.5
# 2018-09-03     11.9
# 2018-09-04     11.2
# 2018-09-05     12.5

# %%
df4 = df4.reset_index()

# %%
df4['datum'] = pd.to_datetime(df4['just_date'])

# %%
teplota_df = pd.merge(novy_df, df4,on='datum',how='left')

# %%
teplota_df.plot.scatter(x="teplota", y="index", color="lightgreen")
plt.ylabel('Number of rented bicycles per day', fontsize=14)
plt.title('Renting bicycles vs Temperature', fontsize=20)
plt.xlabel('Temperature', fontsize=14)
plt.show()

# %% [markdown]
# Z výše zobrazeného grafu vidíme, že s rostoucí teplotou roste i poptávka po půjčování kol.

# %%
#DataFrame df_poryv - vztah mezi počtem výpůjček a poryvy větru
df_poryv = weather_df.set_index('just_date')
df_poryv['poryv'] = df_poryv['gust'].str.replace('km/h', '')
df_poryv['poryv'] = df_poryv.poryv.astype(float)
df_poryv = df_poryv.groupby('just_date').mean('gust').round(1)

# %%
df_poryv = df_poryv.reset_index()

# %%
df_poryv['datum'] = pd.to_datetime(df_poryv['just_date'])

# %%
poryv_df = pd.merge(novy_df, df_poryv,on='datum',how='left')

# %%
poryv_df.plot.scatter(x="poryv", y="index", color="lime")
plt.ylabel('Number of rented bicycles per day', fontsize=14)
plt.title('Renting bicycles vs Gust', fontsize=20)
plt.xlabel('Gust', fontsize=14)
plt.show()

# %% [markdown]
# Z výše vyobrazeného grafu vidíme, že nejvíce půjčených kol bývá při nízkém poryvu větru.

# %%
#DataFrame df_cloud - vztah mezi počtem výpůjček a oblačností
df_cloud = weather_df.set_index('just_date')
df_cloud['oblacnost'] = df_cloud['cloud'].str.replace('%', '')
df_cloud['oblacnost'] = df_cloud.oblacnost.astype(float)
df_cloud = df_cloud.groupby('just_date').mean('cloud').round(1)

# %%
df_cloud = df_cloud.reset_index()

# %%
df_cloud['datum'] = pd.to_datetime(df_cloud['just_date'])

# %%
cloud_df = pd.merge(novy_df, df_cloud,on='datum',how='left')

# %%
cloud_df.plot.scatter(x="oblacnost", y="index", color="darkgrey")
plt.ylabel('Number of rented bicycles per day', fontsize=14)
plt.title('Renting bicycles vs Cloud', fontsize=20)
plt.xlabel('Cloud', fontsize=14)
plt.show()

# %% [markdown]
# Z výše zobrazeného grafu vidíme, že při vysoké oblačnosti se kola půjčují méně, než když je oblačnost nízká. Vypadá, že vysoká oblačnost je v Edingburghu častý jev.

# %% [markdown]
# ##Půjčují si lidé kola více o víkendu než během pracovního týdne?

# %%
bikes_df2['started_at'] = pd.to_datetime(bikes_df2['started_at'])
# Out:
# <ipython-input-287-5353f9f5448a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikes_df2['started_at'] = pd.to_datetime(bikes_df2['started_at'])

# %%
bikes_df2['weekday'] = bikes_df2['started_at'].dt.weekday
# Out:
# <ipython-input-288-08cfc48c7b1a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bikes_df2['weekday'] = bikes_df2['started_at'].dt.weekday

# %%
df3 = bikes_df2.groupby("weekday")[['index']].count()
df3.rename(index={0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}).head(4)
# Out:
#            index
# weekday
# Monday     37784
# Tuesday    38937
# Wednesday  39957
# Thursday   40706

# %%
fig, ax = plt.subplots(figsize=(8,8))
colors = ['lightblue', 'gold','lightgreen', 'pink', 'yellow', 'grey', 'lightcoral']
labels = [r'Monday', r'Tuesday', 
r'Wednesday', r'Thursday', r'Friday', r'Saturday', r'Sunday']
ax.pie(df3.values.flatten(), colors=colors,autopct='%1.1f%%', shadow=True, startangle=50, labels=labels)
ax.set_title("Renting bikes according to days", fontsize=20)
plt.legend(labels, loc="best")
plt.show()

# %% [markdown]
# Z koláčového grafu vidíme, že poptávka po kolech je větší během víkendu než v pracovní dny. Během pracovního týdne je poptávka velmi podobná, kolem 13-14%, je možné, že tuto službu využívají někteří pravidelně k dojíždění do školy či do práce. A o víkendu se k nim pak přidává skupina výletníků:)

# %% [markdown]
# ##Spočítejte vzdálenosti mezi jednotlivými stanicemi.

# %%
vzdalenosti_df = bikes_df.set_index('start_station_name')[['start_station_latitude', 'start_station_longitude']]

# %%
vzdalenosti_df = vzdalenosti_df.drop_duplicates().sort_values(by='start_station_name')

# %%
maly_df = vzdalenosti_df.iloc[:15, :]

# %%
maly_df = maly_df.reset_index()

# %%
maly_df['start_station_latitude'] = np.radians(maly_df['start_station_latitude'])
maly_df['start_station_longitude'] = np.radians(maly_df['start_station_longitude'])

# %%
dist = DistanceMetric.get_metric('haversine')

# %%
maly_df[['start_station_latitude','start_station_longitude']].to_numpy()
# Out:
# array([[ 0.97660331, -0.05536562],
#        [ 0.97631864, -0.05674368],
#        [ 0.97631871, -0.05674259],
#        [ 0.97654616, -0.0563065 ],
#        [ 0.97633843, -0.0561182 ],
#        [ 0.9770808 , -0.05901752],
#        [ 0.976439  , -0.05565948],
#        [ 0.97644198, -0.05565271],
#        [ 0.97670112, -0.05551868],
#        [ 0.97670248, -0.05551902],
#        [ 0.97628759, -0.05596285],
#        [ 0.97628697, -0.05596279],
#        [ 0.97673519, -0.05578567],
#        [ 0.97653791, -0.05590611],
#        [ 0.97645528, -0.0558861 ]])

# %%
dist.pairwise(maly_df[['start_station_latitude','start_station_longitude']].to_numpy())*6373
# Out:
# array([[0.00000000e+00, 5.24172217e+00, 5.23791185e+00, 3.37677424e+00,
#         3.17208872e+00, 1.33756282e+01, 1.48188915e+00, 1.45141360e+00,
#         8.28665611e-01, 8.36007786e-01, 2.93104469e+00, 2.93359921e+00,
#         1.71815077e+00, 1.97300274e+00, 2.08308393e+00],
#        [5.24172217e+00, 0.00000000e+00, 3.92266249e-03, 2.12993452e+00,
#         2.23610052e+00, 9.45465371e+00, 3.94486219e+00, 3.97224721e+00,
#         5.00491696e+00, 5.00808195e+00, 2.79413081e+00, 2.79462867e+00,
#         4.32813871e+00, 3.29962385e+00, 3.18215702e+00],
#        [5.23791185e+00, 3.92266249e-03, 0.00000000e+00, 2.12677732e+00,
#         2.23218435e+00, 9.45776570e+00, 3.94095271e+00, 3.96833888e+00,
#         5.00129659e+00, 5.00446405e+00, 2.79027498e+00, 2.79077386e+00,
#         4.32478790e+00, 3.29590487e+00, 3.17828665e+00],
#        [3.37677424e+00, 2.12993452e+00, 2.12677732e+00, 0.00000000e+00,
#         1.48465925e+00, 1.02522798e+01, 2.40775445e+00, 2.42564785e+00,
#         2.97919358e+00, 2.98093068e+00, 2.05415012e+00, 2.05744514e+00,
#         2.21447979e+00, 1.42964857e+00, 1.60807118e+00],
#        [3.17208872e+00, 2.23610052e+00, 2.23218435e+00, 1.48465925e+00,
#         0.00000000e+00, 1.13734779e+01, 1.75816091e+00, 1.78757312e+00,
#         3.14944565e+00, 3.15499219e+00, 6.42196276e-01, 6.44381076e-01,
#         2.79309290e+00, 1.47953883e+00, 1.11386347e+00],
#        [1.33756282e+01, 9.45465371e+00, 9.45776570e+00, 1.02522798e+01,
#         1.13734779e+01, 0.00000000e+00, 1.26573386e+01, 1.26740471e+01,
#         1.27105294e+01, 1.27076732e+01, 1.20127264e+01, 1.20145867e+01,
#         1.17341568e+01, 1.16245277e+01, 1.18597915e+01],
#        [1.48188915e+00, 3.94486219e+00, 3.94095271e+00, 2.40775445e+00,
#         1.75816091e+00, 1.26573386e+01, 0.00000000e+00, 3.06972858e-02,
#         1.74436253e+00, 1.75232457e+00, 1.45034885e+00, 1.45281708e+00,
#         1.94057030e+00, 1.08253827e+00, 8.15387666e-01],
#        [1.45141360e+00, 3.97224721e+00, 3.96833888e+00, 2.42564785e+00,
#         1.78757312e+00, 1.26740471e+01, 3.06972858e-02, 0.00000000e+00,
#         1.71934323e+00, 1.72734237e+00, 1.48098847e+00, 1.48345267e+00,
#         1.92792736e+00, 1.09151820e+00, 8.37203322e-01],
#        [8.28665611e-01, 5.00491696e+00, 5.00129659e+00, 2.97919358e+00,
#         3.14944565e+00, 1.27105294e+01, 1.74436253e+00, 1.71934323e+00,
#         0.00000000e+00, 8.76164491e-03, 3.07530230e+00, 3.07857392e+00,
#         9.76890496e-01, 1.72988141e+00, 2.04284623e+00],
#        [8.36007786e-01, 5.00808195e+00, 5.00446405e+00, 2.98093068e+00,
#         3.15499219e+00, 1.27076732e+01, 1.75232457e+00, 1.72734237e+00,
#         8.76164491e-03, 0.00000000e+00, 3.08211423e+00, 3.08538980e+00,
#         9.73808326e-01, 1.73414132e+00, 2.04872864e+00],
#        [2.93104469e+00, 2.79413081e+00, 2.79027498e+00, 2.05415012e+00,
#         6.42196276e-01, 1.20127264e+01, 1.45034885e+00, 1.48098847e+00,
#         3.07530230e+00, 3.08211423e+00, 0.00000000e+00, 3.95148166e-03,
#         2.92175718e+00, 1.60806547e+00, 1.10322065e+00],
#        [2.93359921e+00, 2.79462867e+00, 2.79077386e+00, 2.05744514e+00,
#         6.44381076e-01, 1.20145867e+01, 1.45281708e+00, 1.48345267e+00,
#         3.07857392e+00, 3.08538980e+00, 3.95148166e-03, 0.00000000e+00,
#         2.92556309e+00, 1.61195278e+00, 1.10699002e+00],
#        [1.71815077e+00, 4.32813871e+00, 4.32478790e+00, 2.21447979e+00,
#         2.79309290e+00, 1.17341568e+01, 1.94057030e+00, 1.92792736e+00,
#         9.76890496e-01, 9.73808326e-01, 2.92175718e+00, 2.92556309e+00,
#         0.00000000e+00, 1.32866179e+00, 1.81949256e+00],
#        [1.97300274e+00, 3.29962385e+00, 3.29590487e+00, 1.42964857e+00,
#         1.47953883e+00, 1.16245277e+01, 1.08253827e+00, 1.09151820e+00,
#         1.72988141e+00, 1.73414132e+00, 1.60806547e+00, 1.61195278e+00,
#         1.32866179e+00, 0.00000000e+00, 5.31405527e-01],
#        [2.08308393e+00, 3.18215702e+00, 3.17828665e+00, 1.60807118e+00,
#         1.11386347e+00, 1.18597915e+01, 8.15387666e-01, 8.37203322e-01,
#         2.04284623e+00, 2.04872864e+00, 1.10322065e+00, 1.10699002e+00,
#         1.81949256e+00, 5.31405527e-01, 0.00000000e+00]])

# %%
 pd.DataFrame(dist.pairwise(maly_df[['start_station_latitude','start_station_longitude']].to_numpy())*6373, columns=maly_df.start_station_name, index=maly_df.start_station_name).round(2)
# Out:
# start_station_name  Abbeyhill  Balgreen  Balgreen Road  Belford Road  \
# start_station_name
# Abbeyhill                0.00      5.24           5.24          3.38
# Balgreen                 5.24      0.00           0.00          2.13
# Balgreen Road            5.24      0.00           0.00          2.13
# Belford Road             3.38      2.13           2.13          0.00
# Boroughmuir              3.17      2.24           2.23          1.48
# Borrowman Square        13.38      9.45           9.46         10.25
# Bristo Square            1.48      3.94           3.94          2.41
# Bristo Square            1.45      3.97           3.97          2.43
# Brunswick Place          0.83      5.00           5.00          2.98
# Brunswick Place          0.84      5.01           5.00          2.98
# Bruntsfield              2.93      2.79           2.79          2.05
# Bruntsfield Links        2.93      2.79           2.79          2.06
# Canonmills               1.72      4.33           4.32          2.21
# Castle Street            1.97      3.30           3.30          1.43
# Castle Terrace           2.08      3.18           3.18          1.61
#
# start_station_name  Boroughmuir  Borrowman Square  Bristo Square  \
# start_station_name
# Abbeyhill                  3.17             13.38           1.48
# Balgreen                   2.24              9.45           3.94
# Balgreen Road              2.23              9.46           3.94
# Belford Road               1.48             10.25           2.41
# Boroughmuir                0.00             11.37           1.76
# Borrowman Square          11.37              0.00          12.66
# Bristo Square              1.76             12.66           0.00
# Bristo Square              1.79             12.67           0.03
# Brunswick Place            3.15             12.71           1.74
# Brunswick Place            3.15             12.71           1.75
# Bruntsfield                0.64             12.01           1.45
# Bruntsfield Links          0.64             12.01           1.45
# Canonmills                 2.79             11.73           1.94
# Castle Street              1.48             11.62           1.08
# Castle Terrace             1.11             11.86           0.82
#
# start_station_name  Bristo Square  Brunswick Place  Brunswick Place  \
# start_station_name
# Abbeyhill                    1.45             0.83             0.84
# Balgreen                     3.97             5.00             5.01
# Balgreen Road                3.97             5.00             5.00
# Belford Road                 2.43             2.98             2.98
# Boroughmuir                  1.79             3.15             3.15
# Borrowman Square            12.67            12.71            12.71
# Bristo Square                0.03             1.74             1.75
# Bristo Square                0.00             1.72             1.73
# Brunswick Place              1.72             0.00             0.01
# Brunswick Place              1.73             0.01             0.00
# Bruntsfield                  1.48             3.08             3.08
# Bruntsfield Links            1.48             3.08             3.09
# Canonmills                   1.93             0.98             0.97
# Castle Street                1.09             1.73             1.73
# Castle Terrace               0.84             2.04             2.05
#
# start_station_name  Bruntsfield  Bruntsfield Links  Canonmills  Castle Street  \
# start_station_name
# Abbeyhill                  2.93               2.93        1.72           1.97
# Balgreen                   2.79               2.79        4.33           3.30
# Balgreen Road              2.79               2.79        4.32           3.30
# Belford Road               2.05               2.06        2.21           1.43
# Boroughmuir                0.64               0.64        2.79           1.48
# Borrowman Square          12.01              12.01       11.73          11.62
# Bristo Square              1.45               1.45        1.94           1.08
# Bristo Square              1.48               1.48        1.93           1.09
# Brunswick Place            3.08               3.08        0.98           1.73
# Brunswick Place            3.08               3.09        0.97           1.73
# Bruntsfield                0.00               0.00        2.92           1.61
# Bruntsfield Links          0.00               0.00        2.93           1.61
# Canonmills                 2.92               2.93        0.00           1.33
# Castle Street              1.61               1.61        1.33           0.00
# Castle Terrace             1.10               1.11        1.82           0.53
#
# start_station_name  Castle Terrace
# start_station_name
# Abbeyhill                     2.08
# Balgreen                      3.18
# Balgreen Road                 3.18
# Belford Road                  1.61
# Boroughmuir                   1.11
# Borrowman Square             11.86
# Bristo Square                 0.82
# Bristo Square                 0.84
# Brunswick Place               2.04
# Brunswick Place               2.05
# Bruntsfield                   1.10
# Bruntsfield Links             1.11
# Canonmills                    1.82
# Castle Street                 0.53
# Castle Terrace                0.00

# %% [markdown]
# Tímto způsobem jsem spočítala vzdálenosti mezi jednotlivými stanicemi (v km). Do výpočtu jsem zadala omezený počet stanic (:15). Když jsem zadala všechny, tak to bylo bohužel na výpočet tak náročné, že mi vyskočil memory error.
#
# Na této tabulce jde hezky vidět to, že byly některé stanice v průběhu času trošku posunuté, jejich zeměpisná šířka a délka je od původní trošku posunutá.
